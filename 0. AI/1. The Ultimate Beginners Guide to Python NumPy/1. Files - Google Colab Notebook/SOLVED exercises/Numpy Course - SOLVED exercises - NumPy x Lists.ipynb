# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %% [markdown]
# In this module, you will be invited to redo some of the examples presented in class, to consolidate the concepts.

# %% [markdown]
# ### NumPy x Lists

# %% [markdown]
# #### Fixed size

# %% [markdown]
# Below we will instantiate an array with 4 elements.

# %%
array_a = np.array([0, 1, 2, 3])

# %% [markdown]
# Using the `np.append` function, add the element `4` at the end of this array. Remember that this new element must be "enveloped" in a list: `[4]`. Put the result in new array called `array_b` and display the result.

# %%
array_b = np.append(array_a, [4])

# %%
array_b
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# Now, using Python's `id` function and the `==` comparator, show that the two arrays have different addresses in memory, which shows that `array_b` is different from `array_a`.
#
# 💡 This is because, in NumPy, arrays have a **fixed size**. If you add elements to the array, a new array is created.

# %%
id(array_a) == id(array_b)
# Out:
# False

# %% [markdown]
# #### Homogeneous

# %% [markdown]
# Instantiate an array `array_c` with 3 elements:
# - the number `3` (integer)
# - the number `7.9` (float)
# - the value `False` (boolean)
#
# Display this array.

# %%
array_c = np.array([3, 7.9, False])

# %%
array_c
# Out:
# array([3. , 7.9, 0. ])

# %% [markdown]
# Using a `for` loop to iterate over the elements of `array_c`, display on the screen (`print`) the element itself, and the type of each element in the array, using the `type` function.

# %%
for i in array_c:
    print(i, type(i))
# Out:
# 3.0 <class 'numpy.float64'>
# 7.9 <class 'numpy.float64'>
# 0.0 <class 'numpy.float64'>

# %% [markdown]
# 💡 Note that to maintain the homogeneity of the array, all elements were converted to type `np.float`.

# %% [markdown]
# Now, using the array's `dtype` method, display the type of data it stores.

# %%
array_c.dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Vectorization

# %% [markdown]
# Instantiate an array `array_d` with the values ​​`10`, `11`, `12` and `13`, and an array `array_e` with the values ​​`1`, `2`, `3` and `4`.
#
# Display these two arrays.

# %%
array_d = np.array([10, 11, 12, 13])
array_e = np.array([1, 2, 3, 4])

array_d, array_e
# Out:
# (array([10, 11, 12, 13]), array([1, 2, 3, 4]))

# %% [markdown]
# Now, perform the 4 basic mathematical operations (addition, subtraction, multiplication and division) using the native Python operators (`+`, `-`, `*`, `/`). Display the results directly, without storing them in a variable first.

# %%
array_d + array_e
# Out:
# array([11, 13, 15, 17])

# %%
array_d - array_e
# Out:
# array([9, 9, 9, 9])

# %%
array_d * array_e
# Out:
# array([10, 22, 36, 52])

# %%
array_d / array_e
# Out:
# array([10.  ,  5.5 ,  4.  ,  3.25])

# %% [markdown]
# 💡 The use of basic operators is only possible thanks to the vector nature of NumPy arrays, which allows element-by-element mathematical operations between arrays.

# %% [markdown]
# #### Broadcasting

# %% [markdown]
# Let's reuse `array_d` to demonstrate the broadcasting property.
#
# Use the 4 basic mathematical operators to add, subtract, multiply and divide the value `2` of each element in the array.
#
# Print results directly to the screen.

# %%
array_d
# Out:
# array([10, 11, 12, 13])

# %%
array_d + 2
# Out:
# array([12, 13, 14, 15])

# %%
array_d - 2
# Out:
# array([ 8,  9, 10, 11])

# %%
array_d * 2
# Out:
# array([20, 22, 24, 26])

# %%
array_d / 2
# Out:
# array([5. , 5.5, 6. , 6.5])

# %% [markdown]
# 💡 Note that, if you want to perform these operations on all elements of the array with a **fixed value**, you can use this value as a scalar, without the need to transform it into an array. This is possible thanks to the broadcasting property.
